# %% [markdown]
# # Assignment 1: Modeling
#
# University of California at Berkeley
#
# ME C231A, EE C220B, Experiential Advanced Control I
#
# **Released:** 8/29/2023
#
# **Due on bCourses:** 9/10/2023 at 11:59pm
#
# **Submission Instructions:**
#
#
# *   Make a copy of this colab notebook in your drive. (File -> Save a copy in Drive)
# *   Complete your homework by writing code in your copy of the notebook and writing answers to the written questions.
# * When you are ready to submit, run all your cells so the outputs show in this notebook.
# * Save your colab notebook as a PDF. (File -> Print -> Save as PDF).
# * If required, combine the colab PDF with a PDF of any written answers.
# * Submit two files on bCourses:
#   * Combined PDF of Colab and written answers
#   * Python notebook of Colab (File -> Download -> Download .ipynb)

# %% [markdown]
# ***

# %% [markdown]
# These notes were developed by Fionna Kopp, Charlott Vallon, Roya Firoozi and Francesco Borrelli at UC Berkeley. They are protected by U.S. copyright law and by University policy (https://copyright.universityofcalifornia.edu/resources/ownership-course-materials.html).
#
# If you are enrolled in ME C231A/EE C220B you may take notes and make copies of course materials for your own use. You may also share those materials with another student who is registered and enrolled in this course, and with DSP.
#
# You may not reproduce, distribute or display lecture notes or recordings or course materials in any other way — whether or not a fee is charged — without my express written consent. You also may not allow others to do so. If you do so, you may be subject to student conduct proceedings under the Berkeley Code of Student Conduct, including Sections 102.23 and 102.25.

# %% [markdown]
# ***

# %%
#@title # First, run this cell to generate `sineData.mat`
#@markdown *DO NOT MODIFY THIS CELL*

data = b"""

qYDrYEVgR0N10NZgLiZPxZaGLeHh/wDG+5m/
"""

import base64
data = base64.b64decode(data)
with open('sineData.mat', 'wb') as f:
  f.write(data)
del data
# !md5sum sineData.mat
# Out:
# ac12fa216bb70f96399a44fec88a8092  sineData.mat

# %% [markdown]
# # <font color=blue> Question 1.  Equilibrium Point and Linearization </font>

# %% [markdown]
# <center><img src="data:image/png;base64,..." width="500"/></center>

# %% [markdown]
# Consider an inverted double-pendulum system that consists of two point masses $m=2$ kg on two rods of length $l=6$ m. The rods are supported in a pivot on a horizontal plane with $g = 9.81$ m/s$^2$. At length $a=3$ m they are connected by a spring-damper system. The spring has a spring constant $k = 1.5$ N/s. The damping coefficient is $d = 1$ Ns/m. Its neutral position is at $\theta_1(t)=\theta_2(t)=0$. In the pivot of the left mass, an external torque $T(t)$ can be applied. In the right pivot there is a disturbance torque of the form $\alpha(t)+\beta\dot{\theta}_2^2$, where $\beta = 0.1$ m$^{2}$kg is a constant.
#
# The differential equations representing the dynamics of the system are
#
# \begin{align}
# ml^2\ddot{\theta}_1(t) &= mgl\sin\theta_1(t) +a\cos\theta_1(t) F_{sd}+T(t)\nonumber\\
# ml^2\ddot{\theta}_2 (t) &= mgl\sin\theta_2(t) -a\cos\theta_2(t)  F_{sd}+\alpha(t)+\beta\dot{\theta}_2^2(t) \nonumber
# \end{align}
#
# where $F_{sd}=k\:a(\sin\theta_2(t)  -\sin\theta_1(t) )+d\:a(\dot{\theta}_2(t) -\dot{\theta}_1(t) )$ which gives the following set of differential equations
#
# \begin{align}
# \ddot{\theta}_1 (t) &= \frac{1}{ml^2}\left[mgl\sin\theta_1 (t)+a^2\cos\theta_1(t)\left(k(\sin\theta_2(t) -\sin\theta_1(t))+d(\dot{\theta}_2(t)-\dot{\theta}_1(t))\right)+T(t)\right]\nonumber\\
# \ddot{\theta}_2 (t)&= \frac{1}{ml^2}\left[mgl\sin\theta_2(t)-a^2\cos\theta_2(t)\left(k(\sin\theta_2(t) -\sin\theta_1(t))+d(\dot{\theta}_2(t)-\dot{\theta}_1(t))\right)+\alpha(t)+\beta\dot{\theta}_2^2(t)\right]\nonumber
# \end{align}

# %% [markdown]
# **Part (a)**
#
# For any fixed values of $\theta_2$  and $\alpha$ (denoted ${\bar \theta}_2$ and $\bar \alpha$), there
# exist unique values of
# $T$ and $\theta_1$ ($\bar T$ and ${\bar \theta}_1$) such the system is in equilibrium (with ${\dot \theta}_1 = {\dot \theta}_2 = 0$, of course).  Write a function $\texttt{EquilPoint}$, with function declaration:

# %% [markdown]
# `def EquilPoint(theta2_bar, alpha_bar):
#     return  theta1_bar, T_bar `

# %% [markdown]
# that carries out this calculation.
# All the input and output arguments ($\texttt{alpha_bar}$, $\texttt{theta2_bar}$, $\texttt{theta1_bar}$ and $\texttt{T_bar}$) are scalar valued.

# %% [markdown]
# ### <font color=red> Deliverable 1a (5 pts): write your answer in the code cell below</font>

# %%
import numpy as np
from numpy import sin, cos, tan, arcsin

def EquilPoint(theta2_bar, alpha_bar):
    # Write your code here:

    # Given constant values
    m, g, l, k, a, d, beta = 2, 9.81, 6, 1.5, 3, 1, 0.1

    theta1_bar = arcsin(-(m*g*l)*tan(theta2_bar)/(k*a*a) + sin(theta2_bar) - alpha_bar/(k*a*a*cos(theta2_bar)))
    T_bar = -m*g*l*sin(theta1_bar) - k*a*a*cos(theta1_bar)*(sin(theta2_bar) - sin(theta1_bar))

    return  theta1_bar, T_bar

# Please submit the results of the following unit test
theta1_bar, T_bar = EquilPoint(theta2_bar=0.1, alpha_bar=0.5)
print(theta1_bar)
print(T_bar)
# Out:
# -0.9480984252240132
# 88.44306254140136

# %% [markdown]
# **Part (b)**
#
# Next we want to compute the Jacobian linearization about such an equilibrium point. Denote
# \begin{align}
# \bar x := \left[ \begin{array}{c}
# {\bar \theta}_1 \\ {\bar {\dot \theta}}_1 \\
# {\bar \theta}_2 \\ {\bar {\dot \theta}}_2 \end{array} \right], \ \ \ \ \
# \bar u := \left[ \begin{array}{c}
# {\bar T} \\ {\bar \alpha} \end{array}  \right], \ \ \ \
# \bar y = {\bar \theta}_1
# \end{align}
#
# Deviations from equilibrium point are denoted $x$, $u$ and $y$, namely
#
# \begin{align}
# x(t) := \left[ \begin{array}{c} \theta_1 (t) \\ {\dot \theta}_1 (t) \\ \theta_2 (t) \\ {\dot \theta}_2 (t) \end{array}
# \right] - \bar x, \ \ \ \ \
# u(t) := \left[ \begin{array}{c} T (t) \\ \alpha (t)  \end{array}
# \right] - \bar u, \ \ \ \ \
# y(t) := \theta_1 (t) - \bar y
# \end{align}
#
# and, to first-order, are governed by linear differential equations of the form
# 	    \begin{align}
# 	    	\dot{x}(t) &= Ax(t)+Bu(t)\nonumber\\
# 	    	y(t)       &= Cx(t)+Du(t)\nonumber
# 	    \end{align}
# where the matrices $A, B, C$ and $D$ depend on the equilibrium point and the underlying nonlinear differential equations
# for the system.
#
# Write a function called $\texttt{LinearizeModel}$ with function declaration line:

# %% [markdown]
# `def LinearizeModel(theta2_bar, alpha_bar):
#     return A, B, C, D, theta1_bar, T_bar`

# %% [markdown]
# that carries out this calculation at any given value of $({\bar \theta}_2, \bar \alpha)$.  This function, $\texttt{LinearizeModel}$ should call the equilibrium point function $\texttt{EquilPoint}$
# to determine ${\bar \theta}_1$ and $\bar T$ and also return these as the 5th and 6th output arguments.

# %% [markdown]
# ### <font color=red> Deliverable 1b (15 pts): write your answer in the code cell below</font>

# %%
import sympy as sym
from sympy import *
import numpy as np
from numpy import sin, cos, tan, arcsin

# Hint: use SymPy to compute jacobians.

def LinearizeModel(theta2_bar, alpha_bar):
    # Write your code here:

    # Given constant values
    m, g, l, k, a, d, beta = 2, 9.81, 6, 1.5, 3, 1, 0.1

    # Variables
    theta1, theta2, theta1_dot, theta2_dot, T, alpha= sym.symbols('theta1, theta2, theta1_dot, theta2_dot, T, alpha')

    # Assign values to theta1_bar, theta1_dot_bar, theta2_dot_bar, T_bar
    tetha1_bar, T_bar = EquilPoint(theta2_bar, alpha_bar)
    theta1_dot_bar, theta2_dot_bar = 0, 0

    # Declare x, x_bar, u, u_bar, f_xu, y
    x = [theta1, theta1_dot, theta2, theta2_dot]
    x_bar = [theta1_bar, theta1_dot_bar, theta2_bar, theta2_dot_bar]

    u = [T, alpha]
    u_bar = [T_bar, alpha_bar]

    f_xu = [theta1_dot,
            g/(m*l*l)*(m*g*l*sym.sin(theta1)+a*a*sym.cos(theta1)*(k*(sym.sin(theta2)-sym.sin(theta1))+d*(theta1_dot-theta2_dot))+T),
            theta2_dot,
            g/(m*l*l)*(m*g*l*sym.sin(theta2)-a*a*sym.cos(theta2)*(k*(sym.sin(theta2)-sym.sin(theta1))+d*(theta1_dot-theta2_dot))+alpha+beta*theta2_dot*theta2_dot)]
    y = [theta1 - theta1_bar]

    # Get A, B, C, D
    A = sym.Matrix(f_xu).jacobian(x)
    Asub = A.subs([(theta1, theta1_bar), (theta1_dot, theta1_dot_bar), (theta2, theta2_bar), (theta2_dot, theta2_dot_bar), (T, T_bar), (alpha, alpha_bar)])

    B = sym.Matrix(f_xu).jacobian(u)
    Bsub = B.subs([(theta1, theta1_bar), (theta1_dot, theta1_dot_bar), (theta2, theta2_bar), (theta2_dot, theta2_dot_bar), (T, T_bar), (alpha, alpha_bar)])

    C = sym.Matrix(y).jacobian(x)
    D = sym.Matrix(y).jacobian(u)
    return Asub, Bsub, C, D, theta1_bar, T_bar

# Please submit the results of the following unit test
theta2_bar = 0.1
alpha_bar = 0.5
A, B, C, D, theta1_bar, T_bar = LinearizeModel(theta2_bar, alpha_bar)
print('A = ', A)
print('B = ', B)
print('C = ', C)
print('D = ', D)
print('theta1_bar = ', theta1_bar)
print('T_bar = ', T_bar)
# Out:
# A =  Matrix([[0, 1, 0, 0], [10.0918026569026, 0.715184324901575, 1.06741707332793, -0.715184324901575], [0, 0, 0, 1], [1.06741707332793, -1.22012385767218, 14.3056750862738, 1.22012385767218]])
# B =  Matrix([[0, 0], [0.136250000000000, 0], [0, 0], [0, 0.136250000000000]])
# C =  Matrix([[1, 0, 0, 0]])
# D =  Matrix([[0, 0]])
# theta1_bar =  -0.9480984252240132
# T_bar =  88.44306254140136

# %% [markdown]
# **Part (c)**
#
# In part b we wrote a function to generate the linear model of the dynamics around an equilibrium point. Under what circumstances will this linearized model be a valid model to use and similar to the nonlinear dynamics?

# %% [markdown]
# ### <font color=red> Deliverable 1c (5 pts): write your answer in your PDF submission or in a text cell here</font>

# %% [markdown]
# ***

# %% [markdown]
# # <font color=blue> Question 2. Euler Discretization of a Building Heat Transfer Model
# Consider the nonlinear heat transfer dynamics building room temperature with forced air ventilation:
# \begin{align}
# m_z c_z \dot{T}(t) = q(t) + c_pu_1(t)(u_2(t) - T(t))
# \end{align}
# where
#
# \begin{equation}
# \begin{aligned}
# T(t) &= \text{room temperature} \nonumber \\
# u_1(t) &= \text{air mass flow rate} \nonumber \\
# u_2(t) &= \text{supply air temperature} \nonumber.\\
# q(t) &= \text{ heat load} \nonumber \\
# m_z &= \text{effective room mass (constant)}  \nonumber \\
# c_z &= \text{effective room heat capacity (constant)} \nonumber \\
# c_p &= \text{heat capacity of air (constant)} \nonumber \\
# %u &= \text{ heat power input}
# \end{aligned}
# \end{equation}
#
# **Part (a)**
#
# Write a function $\texttt{bldgHTM}$, with function declaration line:

# %% [markdown]
# `def bldgHTM(T, u1, u2, q, mz, cz, cp):
#     return Tdot`

# %% [markdown]
# that implements this model, returning $\dot T(t)$, given the values $T(t), u_1 (t), u_2 (t), q(t)$ and the values for the
# 3 fixed parameters.
#
# Note that for this system, the state of the system is the temperature $T$ of the room, the input $u_1$ is airflow rate (usually controlled through a fan), the input $u_2$ is the temperature of the air entering the room (usually controlled with a heating or cooling coil). Everything else is a model parameter.
# For this exercise we will use the values $T_s=0.1$, $c_p= 1000$, $m_z= 100$ and $c_z=20$.

# %% [markdown]
# ### <font color=red> Deliverable 2a (5 pts): write your answer in the code cell below </font>

# %%
def bldgHTM(T, u1, u2, q, mz, cz, cp):
    # Write your code here:
    Tdot = 1/(mz*cz)*(q + cp*u1*(u2-T))
    return Tdot

# Please submit the results of the following unit test
Tdot = bldgHTM(T=60, u1=0.001, u2 = 10, q=1000,  mz=100, cz=20, cp=1000)
print(Tdot)
# Out:
# 0.47500000000000003

# %% [markdown]
# **Part (b)**
#
# Do a Forward Euler Discretization to take this model from continuous time to discrete time. Assume you are given the discrete time load $q(k)$.
# Write a function:

# %% [markdown]
# `def eulerDiscretization(T,q,u1,u2,Ts):
#     return T_KplusOne`

# %% [markdown]
# to get $T(k+1)$ as a function of the inputs $u_1(k), u_2(k)$, state $T(k)$, load $q(k)$, and sampling time $Ts$. $\textbf{Note:}$ All the input and output arguments ($\texttt{T}$, $\texttt{q}$, $\texttt{u1}$, $\texttt{u2}$ and $\texttt{T}_\texttt{KplusOne}$, $\texttt{Ts}$) are scalars.

# %% [markdown]
# ### <font color=red> Deliverable 2b (15 pts): write your answer in the code cell below</font>

# %%
def eulerDiscretization(T,q,u1,u2,Ts):
  mz = 100
  cz = 20
  cp = 1000
  # Write your code here:
  T_KplusOne = T + Ts * 1/(mz*cz)*(q+cp*u1*(u2-T))
  return T_KplusOne

# Please submit the results of the following unit test
T_KplusOne = eulerDiscretization(T=60, q=1000, u1=0.001, u2 = 100, Ts = 0.1)
print(T_KplusOne)
# Out:
# 60.052

# %% [markdown]
# **Part (c)**
#
# Discuss how the following factors:
# * system stability
# * input rate
# * available computation
#
# would affect your choice of Ts for discretization of system dynamics. What effect do each of these factors have on discretized approximations?

# %% [markdown]
# ### <font color=red> Deliverable 2c (5 pts): write your answer in your PDF submission or in a text cell here </font>

# %% [markdown]
# ***

# %% [markdown]
# # <font color=blue> Question 3. Simulation of Nonlinear Bicycle Dynamics

# %% [markdown]
# <center><img src="data:image/png;base64,..." width="300"/> </center>

# %% [markdown]
# Consider a simplified kinematic bicycle model:
#
# \begin{align}
# \dot{x} &= v \cos(\psi+\beta)\\
# \dot{y} &= v \sin(\psi+\beta)\\
# \dot{v} &= a \\
# \dot{\psi} &= \frac{v}{l_r} \sin(\beta)\\
# \beta &= \tan^{-1} \left( \frac{l_r}{l_f+l_r}  \tan(\delta_f)\right)
# \end{align}

# %% [markdown]
# where
# \begin{align}
# x &= \text{ global x coordinate} \nonumber \\
# y &= \text{ global y coordinate} \nonumber \\
# v &= \text{ speed of the vehicle} \nonumber \\
# \psi &= \text{ global heading angle} \nonumber \\
# \beta &= \text{ angle of the current velocity with respect to the longitudinal axis of the car} \nonumber \\
# a &= \text{ acceleration of the center of mass into this direction} \nonumber \\
# l_r &= \text{ distance from the center of mass of the vehicle to the rear axle} \nonumber \\
# l_f &= \text{ distance from the center of mass of the vehicle to the front axle} \nonumber\\
# \delta_f &= \text{ steering angle of the front wheels with respect to the longitudinal axis of the car} \nonumber
# \end{align}
#
# For this problem, you will simulate the car's movement given a predetermined input sequence. The states are $x, y, v, \psi$, and the inputs are $a, \delta_f$. Use $l_f=l_r = 1.738$.
# For this problem, assume that the input is directly $\beta$ (i.e., $\beta(k)$ which has been precomputed based on $\delta_f(k)$, $l_f$ and $l_r$.
#
#
# **Part (a)** Find a Forward Euler discretization of the kinematic model using a sampling time $T_s = 0.1$. Write a function:

# %% [markdown]
# `def carModel(beta,a,x,y,v,psi):
#     return x_out,y_out,v_out,psi_out`

# %% [markdown]
# that takes as its inputs the current state and the current control action and outputs the state at the next time step using the discrete model you derive.
# $\textit{Note:}$ All the input and output arguments are scalar.

# %% [markdown]
# ### <font color=red> Deliverable 3a (5 pts): write your answer in the code cell below</font>

# %%
import matplotlib.pyplot as plt
from numpy import cos, sin

def carModel(beta, a, x, y, v, psi):
    l_r   = 1.738
    dt = 0.1

    # Write your code here:

    x_out = x + dt * v * cos(psi + beta)
    y_out = y + dt * v * sin(psi + beta)
    v_out = v + dt * a
    psi_out = psi + dt * v * sin(beta) / l_r

    return x_out, y_out, v_out, psi_out

# Please submit the results of the following unit test
x, y, v, psi = carModel(0.1,2,5,2,0.1,10)
print(x)
print(y)
print(v)
print(psi)
# Out:
# 4.992194318198308
# 1.9937492935110712
# 0.30000000000000004
# 10.000574415515805

# %% [markdown]
# **Part (b)** Write a function:

# %% [markdown]
# `def sim(time,a,beta,x0):
#     return xtrend,ytrend,vtrend,psitrend`

# %% [markdown]
# which simulates the system states starting at the initial state with given sequences of $\texttt{time}$ and inputs $\texttt{a}$ and $\texttt{beta}$. $\texttt{time}$ is a vector of sampled time instants with sampling $T_s$ starting at $0$ seconds. You should use the function you write in part a. $\textit{Note:}$ The input arguments ($\texttt{time}$, $\texttt{a}$, $\texttt{beta}$) should be 1001-by-1 vectors. $\texttt{x0}$ should be a 4-by-1 vector. The output arguments should be all 1002-by-1  vectors.

# %% [markdown]
# ### <font color=red> Deliverable 3b (10 pts): write your answer in the code cell below </font>

# %%
from scipy.io import loadmat
Data = loadmat('sineData.mat')
a = Data['a']
beta = Data['beta']
time = Data['time']

Ts = 0.1

def sim(time, a, beta, x0):
    # Write your code here:
    x0 = x0[0].tolist()
    xtrend = [x0[0]]
    ytrend = [x0[1]]
    vtrend = [x0[2]]
    psitrend = [x0[3]]

    for i in range(len(time)):
      x, y, v, psi = xtrend[-1], ytrend[-1], vtrend[-1], psitrend[-1]
      x_out, y_out, v_out, psi_out = carModel(beta[i][0], a[i][0], x, y, v, psi)
      xtrend.append(x_out)
      ytrend.append(y_out)
      vtrend.append(v_out)
      psitrend.append(psi_out)

    return np.asarray(xtrend, dtype=object), np.asarray(ytrend, dtype=object), np.asarray(vtrend, dtype=object), np.asarray(psitrend, dtype=object)

# Please submit the results of the following unit test
x = 0.0
y = 0.0
v = 0.0
psi = 0.0

numSteps = len(time)
x0 = np.array([[x, y, v, psi]])
xtrend, ytrend, psitrend, vtrend = sim(time, a, beta, x0)
print("x final: {}".format(xtrend[-1].item()))
print("y final: {}".format(ytrend[-1].item()))
print("v final: {}".format(vtrend[-1].item()))
print("psi final: {}".format(psitrend[-1].item()))
# Out:
# x final: 750.0721182181506
# y final: 4.046338103842894
# v final: 0.013501061009206106
# psi final: 7.83269163649518

# %% [markdown]
#  **Part (c)** Create two plots:
#
#
# *   A plot of each state (x, y, psi, v) versus time (use subplot function)
# *   A plot showing the trajectory of the bicycle ($x$ vs $y$) with time

# %% [markdown]
# ### <font color=red> Deliverable 3c (10 pts): write your answer in the code cell below</font>

# %%
import matplotlib.pyplot as plt
# Plot trajectory
from matplotlib import rc
from IPython.display import HTML

# Write your code here:
# Code for Plot 1

time = [t[0] for t in time]
time.append(time[-1]+0.1)

fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(time, xtrend, 'tab:blue')
axs[0, 0].set_title('x trend')
axs[0, 1].plot(time, ytrend, 'tab:orange')
axs[0, 1].set_title('y trend')
axs[1, 0].plot(time, vtrend, 'tab:green')
axs[1, 0].set_title('v trend')
axs[1, 1].plot(time, psitrend, 'tab:red')
axs[1, 1].set_title('psi trend')

# Code for Plot 2

fig, ax = plt.subplots()
ax.plot(xtrend, ytrend)
ax.set_title('x trend - y trend')
# Out:
# Text(0.5, 1.0, 'x trend - y trend')

# %% [markdown]
# ***

# %% [markdown]
# # <font color=blue> Question 4. ZOH Discretization with Constant and Dynamic Inputs </font>
#
# **Part a:** The dynamics for a simple pendulum system are given as:
# \begin{align}
# \left[ \begin{array}{c}
# {\dot \theta} \\ {\ddot \theta} \end{array} \right] =
# \left[ \begin{array}{c}
# {\dot \theta} \\
# -\frac{g}{l} {\sin \theta} \end{array}  \right] +
# \left[ \begin{array}{c}
# 0 \\ \frac{1}{ml^2} \end{array} \right]T
# \end{align}
#
# The linearized system dynamics are
# \begin{align}
# \left[ \begin{array}{c}
# {\Delta \dot \theta} \\ {\Delta \ddot \theta} \end{array} \right] =
# \left[ \begin{array}{c}
# 0 & 1 \\
# -\frac{g}{l} {\cos \theta} & 0 \end{array} \right]
# \left[ \begin{array}{c}
# {\Delta \theta} \\ {\Delta \dot \theta} \end{array} \right] +
# \left[ \begin{array}{c}
# 0 \\ \frac{1}{ml^2} \end{array} \right]
# \end{align}
#
# evaluated at the equilibrium point. We know the equilibrium point of a simple pendulum is $(\theta, \dot \theta) = (0, 0)$ with $u = 0$. Evaluating at this point:
# \begin{align}
# \left[ \begin{array}{c}
# {\dot \theta} \\ {\ddot \theta} \end{array} \right]  =
# \left[ \begin{array}{c}
# 0 & 1 \\
# -\frac{g}{l} & 0 \end{array} \right]
# \left[ \begin{array}{c}
# {\theta} \\ { \dot \theta} \end{array} \right] +
# \left[ \begin{array}{c}
# 0 \\ \frac{1}{ml^2} \end{array} \right]
# \end{align}
#
#
# Let the output of the system be $y(t) = \theta(t)$.
#
# Calculate the ZOH discretization matrices for the system with $T_s = 0.1$.

# %% [markdown]
# ### <font color=red> Deliverable 4 (5 pts): write your answer in the code cell below </font>

# %%
from scipy.signal import cont2discrete

g = 9.81
l = 1
m = 1

t0 = 0
tf = 4

x0 = np.array([0, 0])
Ts = 0.1

# write your code here:

# ZOH system
# Ad = e^(ATs)
#      (Ts
# Bd = |  e^(At) B dt
#      )0

A = np.array([[0, 1], [-g/l, 0]])
B = np.array([[0], [1/(m*l*l)]])
C = np.array([[1., 0]])
D = np.array([[0.]])

d_system = cont2discrete((A, B, C, D), Ts, method='zoh')
Ad = d_system[0]
Bd = d_system[1]

print(Ad)
print(Bd)
# Out:
# [[ 0.95134967  0.098373  ]
#  [-0.96503914  0.95134967]]
# [[0.00495926]
#  [0.098373  ]]

# %% [markdown]
# **Part b:** When the input is held constant over the sampling interval, what is the difference between the continuous-time model output and the ZOH discrete-time model output? Discuss.

# %% [markdown]
# ### <font color=red> Deliverable 4 (5 pts): write your answer in your pdf submission </font>

# %% [markdown]
# ***

# %% [markdown]
# # <font color=blue> Question 5. Linearization and Discretization </font>
#
# Consider a nonlinear system of the form
#
# \begin{align}
# \dot{x}^c(t) = g(x^c(t), u^c(t))
# \end{align}
#
# which we would like to linearize and discretize using the forward Euler method to arrive at a model of the form
#
# \begin{align}
# x(k+1) = Ax(k) + Bu(k)
# \end{align}
#
# Does it matter whether we linearize or discretize first? Show why or why not.

# %% [markdown]
# ### <font color=red> Deliverable 5 (10 pts): Submit math showing your answer in the PDF submission </font>

# %% [markdown]
# ***

# %% [markdown]
# # <font color=blue> Question 6. HW1 Summary/Wrapper </font>
#
# Rate your confidence in your homework solutions and understanding of material.
#
# A) I am very confident and feel great about this content.
#
# B) I am somewhat confident.
#
# C) I am not feeling confident.
#
# Any additional comments? (Comments are optional, but please rate either A/B/C. All choices will receive the full 5 points.)

# %% [markdown]
# ### <font color=red> Deliverable 6 (5 pts): Write your answer in your PDF submission or in a text cell here </font>
